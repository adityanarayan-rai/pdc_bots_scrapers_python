# %%
# Let's import the libraries
import requests
from bs4 import BeautifulSoup

# %%
# Let's save the url
url1 = "https://hertie-scraping-website.vercel.app/"

url2 = "https://hertie-scraping-website.vercel.app/wowimlevel2"

# Now, let's get a request from both the url
response1 = requests.get(url1)
response2 = requests.get(url2)

# Let's also confirm if we get response for both the url
if response1.status_code == 200:
    print("Successfully fetched the webpage!")
else:
    print("Failed to fetch the webpage. Status code:", response1.status_code)

if response2.status_code == 200:
    print("Successfully fetched the webpage!")
else:
    print("Failed to fetch the webpage. Status code:", response2.status_code)
# Out:
# Successfully fetched the webpage!
# Successfully fetched the webpage!

# %%
soup1 = BeautifulSoup(response1.text, 'html.parser')

soup2 = BeautifulSoup(response2.text, 'html.parser')

# %%
flag1 = soup1.find(id = 'nesting-1').p.text
print(flag1)

flag2 = soup1.find(id = 'nesting-2').p.text
print(flag2)

flag3 = soup1.find(id = "flag-7", class_='text-base').text
print(flag3)

flag4 = soup1.find_all(id="nesting-4")[0].p.text
print(flag4)

flag5 = soup1.find(id="nesting-5").p.text
print(flag5)

flag6 = soup1.find_all(id="nesting-4")[1].p.text
print(flag6)

flag7 = soup1.find_all(id="nesting-5")[1].find_all('p')[0].text
print(flag7)

flag8 = soup1.find(class_="text-transparent").text
print(flag8)

img_tag = soup1.find('img')
flag9 = img_tag['alt'] if img_tag else 'Not Found'
print(flag9)

flag10 = soup1.find("div", class_="size-10")
if flag10:
    print("flag-10")
else:
    print("Flag-10 not found")

flag11 = soup1.find(id="flag-11", class_='')
if flag11:
    print('flag-11')
else:
    print('Flag-11 not found')

flag12 = soup1.find("div", class_="size-10")
if flag12:
    print("flag-12")
else:
    print("Flag-12 not found")

flag13 = soup1.find(id="flag-13", class_='')
if flag13:
    print('flag-13')
else:
    print('Flag-13 not found')

flag14 = soup1.find("div", class_="size-10")
if flag14:
    print("flag-14")
else:
    print("Flag-14 not found")

flag15 = soup1.find(id="flag-15", class_='')
if flag15:
    print('flag-15')
else:
    print('Flag-15 not found')

flag16 = soup1.find("div", class_="size-10")
if flag16:
    print("flag-16")
else:
    print("Flag-16 not found")

flag17 = soup1.find(id="flag-17", class_='')
if flag15:
    print('flag-17')
else:
    print('Flag-17 not found')

flag18 = soup1.find("div", class_="size-10")
if flag18:
    print("flag-18")
else:
    print("Flag-18 not found")

flag19 = soup1.find(id="flag-19", class_='')
if flag19:
    print('flag-19')
else:
    print('Flag-19 not found')

flag20 = soup1.find("div", class_="size-10")
if flag20:
    print("flag-20")
else:
    print("Flag-20 not found")

flag21 = soup1.find(id="flag-21", class_='')
if flag15:
    print('flag-21')
else:
    print('Flag-21 not found')

flag22 = soup1.find("div", class_="size-10")
if flag22:
    print("flag-22")
else:
    print("Flag-22 not found")

flag23 = soup1.find(id="flag-23", class_='')
if flag23:
    print('flag-23')
else:
    print('Flag-23 not found')

flag24 = soup1.find("div", class_="size-10")
if flag24:
    print("flag-24")
else:
    print("Flag-24 not found")

flag25 = soup1.find(id="flag-25", class_='')
if flag25:
    print('flag-25')
else:
    print('Flag-25 not found')

flag26 = soup1.find("div", class_="size-10")
if flag26:
    print("flag-26")
else:
    print("Flag-26 not found")

flag27 = soup1.find(id="flag-27", class_='')
if flag27:
    print('flag-27')
else:
    print('Flag-27 not found')

flag28 = soup1.find("div", class_="size-10")
if flag28:
    print("flag-28")
else:
    print("Flag-28 not found")

flag29 = soup1.find(id="flag-29", class_='')
if flag29:
    print('flag-29')
else:
    print('Flag-29 not found')

flag30 = soup1.find("div", class_="size-10")
if flag30:
    print("flag-30")
else:
    print("Flag-30 not found")

flag31 = soup1.find(id="flag-31", class_='')
if flag31:
    print('flag-31')
else:
    print('Flag-31 not found')

flag32 = soup1.find("div", class_="size-10")
if flag32:
    print("flag-32")
else:
    print("Flag-32 not found")

flag33 = soup1.find(id="flag-33", class_='')
if flag33:
    print('flag-33')
else:
    print('Flag-33 not found')

flag34 = soup1.find("div", class_="size-10")
if flag34:
    print("flag-34")
else:
    print("Flag-34 not found")

flag35 = soup1.find(id="flag-35", class_='')
if flag35:
    print('flag-35')
else:
    print('Flag-35 not found')

flag36 = soup1.find("div", class_="size-10")
if flag36:
    print("flag-36")
else:
    print("Flag-36 not found")

flag37 = soup1.find(id="flag-37", class_='')
if flag37:
    print('flag-37')
else:
    print('Flag-37 not found')

flag38 = soup1.find("div", class_="size-10")
if flag38:
    print("flag-38")
else:
    print("Flag-38 not found")

flag39 = soup1.find(id="flag-39", class_='')
if flag39:
    print('flag-39')
else:
    print('Flag-39 not found')

flag40 = soup1.find("div", class_="size-10")
if flag40:
    print("flag-40")
else:
    print("Flag-40 not found")

flag41 = soup2.find('div', string=lambda text: text and 'flag-41' in text)
if flag41:
    print("flag-41")
else:
    print("Flag not found")

flag42 = soup2.find(class_= 'text-transparent').text
print(flag42)

flag44 = soup2.find('div', string=lambda text: text and 'flag-44' in text)
if flag44:
    print("flag-44")
else:
    print("Flag not found")

flag45 = soup2.find('div', string=lambda text: text and 'flag-45' in text)
if flag45:
    print("flag-45")
else:
    print("Flag not found")

flag48 = soup2.find('div', string=lambda text: text and 'flag-48' in text)
if flag48:
    print("flag-48")
else:
    print("Flag not found")

flag49 = soup2.find('div', string=lambda text: text and 'flag-49' in text)
if flag49:
    print("flag-49")
else:
    print("Flag not found")

flag52 = soup2.find('div', string=lambda text: text and 'flag-52' in text)
if flag52:
    print("flag-52")
else:
    print("Flag not found")

flag53 = soup2.find('div', string=lambda text: text and 'flag-53' in text)
if flag53:
    print("flag-53")
else:
    print("Flag not found")
# Out:
# flag-1
# flag-2
# flag-3
# flag-4
# flag-5
# flag-6
# flag-7
# flag-8
# flag-9
# flag-10
# flag-11
# flag-12
# flag-13
# flag-14
# flag-15
# flag-16
# flag-17
# flag-18
# flag-19
# flag-20
# flag-21
# flag-22
# flag-23
# flag-24
# flag-25
# flag-26
# flag-27
# flag-28
# flag-29
# flag-30
# flag-31
# flag-32
# flag-33
# flag-34
# flag-35
# flag-36
# flag-37
# flag-38
# flag-39
# flag-40
# flag-41
# flag-42
# flag-44
# flag-45
# flag-48
# flag-49
# flag-52
# flag-53
